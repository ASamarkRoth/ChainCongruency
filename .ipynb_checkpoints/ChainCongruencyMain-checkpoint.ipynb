# %% [markdown]
# **Author**: Anton Såmark-Roth <br>
# Mail: <a href="mailto:anton.samark-roth@nuclear.lu.se">anton.samark-roth@nuclear.lu.se</a>

# %% [markdown]
# # Statistical assessment on the congruency of decay chains of superheavy nuclei

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Statistical-assessment-on-the-congruency-of-decay-chains-of-superheavy-nuclei" data-toc-modified-id="Statistical-assessment-on-the-congruency-of-decay-chains-of-superheavy-nuclei-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Statistical assessment on the congruency of decay chains of superheavy nuclei</a></span><ul class="toc-item"><li><span><a href="#About-this-notebook" data-toc-modified-id="About-this-notebook-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>About this notebook</a></span></li></ul></li><li><span><a href="#Examining-the-data" data-toc-modified-id="Examining-the-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Examining the data</a></span><ul class="toc-item"><li><span><a href="#Data-of-interest---Lifetimes-in-decay-chains" data-toc-modified-id="Data-of-interest---Lifetimes-in-decay-chains-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data of interest - Lifetimes in decay chains</a></span></li><li><span><a href="#Motivation---Do-all-decay-chains-in-a-set-have-a-common-origin?" data-toc-modified-id="Motivation---Do-all-decay-chains-in-a-set-have-a-common-origin?-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Motivation - Do all decay chains in a set have a common origin?</a></span></li></ul></li><li><span><a href="#Schmidt-tests-on-the-set-of-short-E115-decay-chains" data-toc-modified-id="Schmidt-tests-on-the-set-of-short-E115-decay-chains-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Schmidt tests on the set of short E115 decay chains</a></span><ul class="toc-item"><li><span><a href="#The-Schmidt-test" data-toc-modified-id="The-Schmidt-test-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>The Schmidt test</a></span></li><li><span><a href="#Generalised-Schmidt-test" data-toc-modified-id="Generalised-Schmidt-test-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Generalised Schmidt test</a></span></li><li><span><a href="#The-generalised-Schmidt-method-applied" data-toc-modified-id="The-generalised-Schmidt-method-applied-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>The generalised Schmidt method applied</a></span><ul class="toc-item"><li><span><a href="#Simulation-of-expected-values-and-confidence-intervals" data-toc-modified-id="Simulation-of-expected-values-and-confidence-intervals-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Simulation of expected values and confidence intervals</a></span></li></ul></li><li><span><a href="#Summary-Generalised-Schmidt-Method" data-toc-modified-id="Summary-Generalised-Schmidt-Method-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Summary Generalised Schmidt Method</a></span></li></ul></li><li><span><a href="#Figure-of-Merit-(FoM)-method" data-toc-modified-id="Figure-of-Merit-(FoM)-method-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Figure-of-Merit (FoM) method</a></span><ul class="toc-item"><li><span><a href="#Simulations" data-toc-modified-id="Simulations-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Simulations</a></span><ul class="toc-item"><li><span><a href="#Simulating-sets-of-decay-chains" data-toc-modified-id="Simulating-sets-of-decay-chains-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Simulating sets of decay chains</a></span><ul class="toc-item"><li><span><a href="#1.-Random-sampling-of-$\tau$-from-its-likelihood-function" data-toc-modified-id="1.-Random-sampling-of-$\tau$-from-its-likelihood-function-4.1.1.1"><span class="toc-item-num">4.1.1.1&nbsp;&nbsp;</span>1. Random sampling of $\tau$ from its likelihood function</a></span></li><li><span><a href="#2.-Simulating-100-000-sets-of-decay-chains-AND-calculating-their-FoM-values." data-toc-modified-id="2.-Simulating-100-000-sets-of-decay-chains-AND-calculating-their-FoM-values.-4.1.1.2"><span class="toc-item-num">4.1.1.2&nbsp;&nbsp;</span>2. Simulating 100 000 sets of decay chains AND calculating their FoM values.</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Summary</a></span></li></ul></li></ul></li><li><span><a href="#The-alleged-link-between-Element-117-and-115" data-toc-modified-id="The-alleged-link-between-Element-117-and-115-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>The alleged link between Element 117 and 115</a></span><ul class="toc-item"><li><span><a href="#Extracting-data" data-toc-modified-id="Extracting-data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Extracting data</a></span></li><li><span><a href="#(i)-Calculations" data-toc-modified-id="(i)-Calculations-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>(i) Calculations</a></span></li><li><span><a href="#(ii)-Simulations" data-toc-modified-id="(ii)-Simulations-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>(ii) Simulations</a></span></li><li><span><a href="#Results-and-Conclusions" data-toc-modified-id="Results-and-Conclusions-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Results and Conclusions</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## About this notebook

# %% [markdown]
# * In this notebook two statistical methods which assesses the congruency of decay chains of superheavy nuclei is presented.
# * The document is started with an introduction to the experimental data of decay chains.
#     * Methods on how to read in the data, filter out the data of interest (lifetimes) and present the data in a table, is shown.
#     * By visualising the lifetime data of the decay chains the need for statistical assessments is motivated.
#
# The two methods are denoted:
# * Generalised Schmidt-test
# * Figure-of-Merit (FoM) method

# %% [markdown]
# These are described subsequently through an example and:
# * Theoretical derivations are shortly presented.
# * Calculations of the experimental data is made.
# * By the means of Monte-Carlo simulations the expected distributions and confidence intervals are obtained.
# * Experimental and simulated data are compared and interpretations are made.
#
# The notebook is concluded with:
# * The FoM method is applied to a compiled data set of Element 117 and 115 decay chains which was used in a IUPAC/IUPAP Joint Working Party report supporting the claims of discovery of E117 and E115. The link between E117 and E115 is assessed.

# %% [markdown]
# The two statistical methods are introduced and thoroughly described in [Ulrika Forsberg's PhD thesis](http://portal.research.lu.se/portal/files/7495513/thesis.pdf) and each method separately in the following papers:
#
# * Schmidt tests: [D. Rudolph et al., EPJ Web of Conferences](https://www.epj-conferences.org/articles/epjconf/pdf/2016/12/epjconf_nn2016_01001.pdf)
# * FoM method: [U. Forsberg et al., Nucl. Phys. A](http://www.sciencedirect.com/science/article/pii/S0375947416300768?via%3Dihub)
# * The alleged link between element 115 and element 117 decay chains:
#     * [U. Forsberg et al., Physics Letters B, ](http://www.sciencedirect.com/science/article/pii/S0370269316303495?via%3Dihub) describes the case in great detail.
#     * [The IUPAC/IUPAP Joint Working Party Report](https://www.degruyter.com/view/j/pac.2016.88.issue-1-2/pac-2015-0502/pac-2015-0502.xml)

# %%
# importing packages
import pandas as pd
import re
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# ignore warnings for nice presentation view
import warnings
warnings.filterwarnings('ignore')

# setting document specific parameters
mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams['font.size'] = 22
mpl.rcParams['figure.figsize'] = (10,8)
mpl.rcParams['ytick.major.width'] = 1.6
mpl.rcParams['xtick.major.width'] = 1.6
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['ytick.minor.width'] = 0.8
mpl.rcParams['xtick.minor.width'] = 0.8
mpl.rcParams['ytick.minor.size'] = 3
mpl.rcParams['xtick.minor.size'] = 3

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'];

# %% [markdown]
# # Examining the data

# %% [markdown]
# All data is obtained from the above-mentioned articles and it has been compiled in one `pandas data frame` and can be found in the file `data/ChainsDataFrame.p`. The data can be read and visualised in the following way:

# %%
df_all = pd.read_pickle('data/ChainsDataFrame.p')
display(df_all)
# Out:
#                            Beam Energy (MeV)  Implantation Energy (MeV)  \
# Element Type  Lab      ID
# E115    3n    GSI      1               242.1                      13.40
#                        2               242.1                      13.90
#                        3               242.1                      16.30
#                        4               242.1                      16.10
#                        5               242.1                      16.40
#                        6               242.1                      15.40
#                        7               242.1                      14.10
#                        8               242.1                      12.50
#                        9               245.0                      15.90
#                        10              245.0                      14.50
#                        11              245.0                      16.50
#                        12              245.0                      15.10
# ...

# %% [markdown]
# All rows of the compiled data table represents experimental measurements of one decay chain. Each decay chain is identified with the 4 indices:
# 2. **Element**: The element studied in the experiment.
# 3. **Type**: For the element 115 chains the type refers to the groups _3n_, _4n_ or _Short_ chains as used in the papers. The 10 element 117 chains that are used in the IUPAC/IUPAP Joint Working Party Report have the type _Link_.
# 1. **Lab**: Laboratory which conducted the experiment.
# 4. **ID**: All chains have an ID which matches the numbers used in the articles.
#
# The column headers present specific measured properties of the chain.
#
# `NaN` could indicate that a certain step is missing, that the chain has already ended or that the value is irrelevant (e.g. this is the case for all columns listing E117 values for an E115 chain).
#
# A $\sigma_E$ value equals to 0 indicates a detected fission and the last step of the chain.

# %% [markdown]
# If one wants to add decay chains to the compiled data table have a look at this notebook: http://localhost:8888/notebooks/AddChainToDataTable.ipynb

# %% [markdown]
# ## Data of interest - Lifetimes in decay chains

# %% [markdown]
# In the context of this notebook it is of interest to extract lifetime data for the _short_ E115 chains. A new data frame with this content can be obtained as follows:

# %%
# Extracting indices with E115 and Short
df_short = df_all.loc[('E115', 'Short')]
#display(df_short)

# Sorting out columns with headers including Lifetime and removing columns with only NaNs
df_short = df_short.filter(regex="Lifetime .* \(s\)").dropna(axis=1, how='all')

display(df_short)
# Out:
# /home/anton/miniconda3/envs/ChainCongruency/lib/python3.6/site-packages/ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#              Lifetime E115 (s)  Lifetime E113 (s)  Lifetime Rg (s)
# Lab      ID
# GSI      1              0.2270             0.3780              NaN
#          2              0.0645             0.3660              NaN
#          3              0.2610             1.1500           0.3430
#          4              1.4600             0.0262           0.4320
#          5              0.3450             0.3690          14.4000
#          6              0.2100             1.0500           8.2700
#          7              0.8150             2.3300           2.8900
# Dubna    1              0.2562             1.4027           1.9775
#          2              0.0661             1.5500           2.3638
#          3              2.3507            22.5822          60.1855
# ...

# %% [markdown]
# ## Motivation - Do all decay chains in a set have a common origin?

# %% [markdown]
# Chains originating from element 115 are divided in two main groups;
# * _3n_
# * _Short_
#
# The division has been made with respect to the number of decay steps that exists in the decay chains.
# The main hypothesis is that each group originates from a common state of a E115 nucleus.
#
# In this case it corresponds to the two different isotopes $^{288}$115 for the 3n chains and $^{289}$115 for the short chains group.
#
# The lifetimes for the different decay steps of the short E115 chains can be further studied:

# %%
ax = (df_short.T).plot(logy=True, use_index=True, xlim=(-0.1, 3.5), marker='o')
plt.title("Lifetimes for the short E115 chains")
plt.xticks(np.arange(3), list(df_short.columns.values), rotation=-10)
plt.ylabel("Lifetime (s)")
plt.legend(fontsize=14, title=r"${\bf Chain}$ (Lab, ID)")
plt.tight_layout()
# Out:
# /home/anton/miniconda3/envs/ChainCongruency/lib/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000

# %% [markdown]
# From the figure above there is one chain that really stands out (note the log scale on the y-axis), the (Dubna, 3) chain or in short D3.
#
# The question arises:
#
# > Do all short E115 decay chains have a common origin, i.e. nuclear state? <br>
# > Does the D3 chain have a different origin compared to the others
#
# To answer the questions two statistical methods have been developed to assess the congruence between decay chains.
# Both methods make use of the well known behaviour of radioactive decays where the lifetimes of one species follow an exponential distribution. The methods are denoted:
#
# * Generalised Schmidt-test
# * Figure-of-Merit (FoM) method
#
# The two methods are introduced and thoroughly described in [Ulrika Forsberg's PhD thesis](http://portal.research.lu.se/portal/files/7495513/thesis.pdf) and each method separately in the following papers:
#
# * Schmidt tests: [D. Rudolph et al., EPJ Web of Conferences](https://www.epj-conferences.org/articles/epjconf/pdf/2016/12/epjconf_nn2016_01001.pdf)
# * FoM method: [U. Forsberg et al., Nucl. Phys. A](http://www.sciencedirect.com/science/article/pii/S0375947416300768?via%3Dihub)
#
# For comparison, let's store two data frames, one with the complete set of _Short_ E115 chains and one excluding (Dubna 3), D3.

# %%
l_df_short = [df_short, df_short.drop(('Dubna', '3'))]

# %% [markdown]
# # Schmidt tests on the set of short E115 decay chains

# %% [markdown]
# ## The Schmidt test

# %% [markdown]
# Around the turn of the millenium [Schmidt et.al](https://link.springer.com/article/10.1007/s100500070129) suggested a new approach on how to assess decay chains.
#
# In the, so called _Schmidt test_, the logarithm of the lifetimes $\theta = \ln t$ and the expected value of its standard deviation ($\sigma_\theta$) of one decay step is considered.
# The fundamental principle of the test is that the shape of the probability density distribution and in continuation the expected value of the standard deviation is independent of the decay constant $\lambda$ of the radioactive species in study.
#
# For an infinite number of events, i.e. an infinite number of measured life times, analytically the expected value of the standard deviation is; $\sigma_\theta = 1.28 \pm 2.15 \cdot \sqrt{m}$ where $m$ is the number of events.
#
# The interpretation of the obtained standard deviation is as follows:
# * A too large value indicates that the set of life times do not originate from one single radioactive species.
# * A too small value indicates a lack of sensitivity in the measurements or that the data is unjustly pruned.
#
# If the _short_ chains of E115 is considered then we arrive at the following values for the Schmidt test:

# %%
Schmidt = np.nanstd(np.log(l_df_short[0]), axis=0)
col_names = []
[col_names.append("Step "+str(i+1)) for i in range(len(Schmidt))]
Schmidt = dict(zip(col_names, Schmidt))
df_Schmidt = pd.DataFrame(data=Schmidt, index=["Experimental Schmidt value"], columns=col_names)
df_Schmidt
# Out:
#                               Step 1   Step 2    Step 3
# Experimental Schmidt value  1.204459  1.75037  1.842351

# %% [markdown]
# Through Monte-Carlo simulations the distribution of this standard deviation could be obtained as a function of the number of events measured.
# [Schmidt et.al](https://link.springer.com/article/10.1007/s100500070129) (Table 1) presents expected values and 90% confidence intervals for $\sigma_\theta$ for a variety of number of events $m$.
#
# Let's add these to the table above.

# %%
Schmidt_conf = [[1.19, 1.19, 1.16], ["[0.73, 1.77]", "[0.73, 1.77]", "[0.65, 1.82]"]]
df_Schmidt.append(pd.DataFrame(data=Schmidt_conf, index=["Expected value of $\sigma_θ$", "90% confidence interval"], columns=col_names))
# Out:
#                                     Step 1        Step 2        Step 3
# Experimental Schmidt value         1.20446       1.75037       1.84235
# Expected value of $\sigma_θ$          1.19          1.19          1.16
# 90% confidence interval       [0.73, 1.77]  [0.73, 1.77]  [0.65, 1.82]

# %% [markdown]
# The Schmidt values from the experimental data does fit in the 90% confidence interval and thus it is justified to draw the conclusion that the data (for each decay step) originates from only one radioactive species.

# %% [markdown]
# ## Generalised Schmidt test

# %% [markdown]
# The Schmidt method is limited to one decay step at a time and hence not all data available is considered. If all steps of the decay chains have common origins a stricter test would be to group all steps of each chain together. An arithmetic average is not sufficient.
#
# A generalisation of the Schmidt test was proposed in [D. Rudolph et al., EPJ Web of Conferences](https://www.epj-conferences.org/articles/epjconf/pdf/2016/12/epjconf_nn2016_01001.pdf) and it is thoroughly described in [Ulrika Forsberg's PhD thesis](http://portal.research.lu.se/portal/files/7495513/thesis.pdf).
#
# Assume that $m$ chains have been observed and that each chain $i$ contains $n_i$ decay steps. Let $\theta_{i_j}$ be the logarithm of the $j$:th lifetime in chain $i$. Then the measure:
#
# \begin{equation}
# \xi_{m, n} = \sqrt[2]{\frac{\sum\limits_{i=1}^m \sqrt[n_i]{\prod\limits_{j=1}^{n_i} \left( \theta_{i_j} - \bar{\theta_j} \right)^2  }  }{m}}, \bar{\theta_j} = \frac{ \sum\limits_{i=1}^m \theta_{i_j} } {m}
# \end{equation}
#
# does incorporate correlation times along decay chains instead of between single decay steps within a set of chains.

# %% [markdown]
# ## The generalised Schmidt method applied

# %% [markdown]
# This section deals with the implementation of the generalised Schmidt method.
#
# To calculate the geometrical mean in an array with `NaN` values the following (non-generic) function is defined.

# %%
def g_nan_mean(data):
    if len(np.shape(data)) == 1:
        return data
    ret = np.empty(np.shape(data)[0])
    for i in range(np.shape(data)[0]):
        temp = 1
        steps = 0
        for j in range(np.shape(data)[1]):
            if isinstance(data, pd.DataFrame) and ~np.isnan(data.iloc[i,j]):
                temp *= data.iloc[i,j]
            elif not isinstance(data, pd.DataFrame) and ~np.isnan(data[i,j]):
                temp *= data[i,j]
            else:
                break
            steps += 1
        ret[i] = temp**(1./steps)
    return ret

# %% [markdown]
# The generalised Schmidt value is calculated for the two sets of decay chains;
# * Complete E115 Short chains.
# * E115 Short chains with D3 excluded.

# %%
gen_Schmidt = []
for dfs in l_df_short:
    #display(dfs)
    theta = np.log(dfs)
    theta_var = np.square(theta - np.nanmean(theta, axis=0))
    gen_Schmidt_temp = g_nan_mean(theta_var)
    gen_Schmidt.append(np.sqrt(np.mean(gen_Schmidt_temp)))

col_names = ["E115 Short chains", "Dubna 3 Excl."]
df_gen_Schmidt = dict(zip(col_names, gen_Schmidt))
df_gen_Schmidt = pd.DataFrame(data=df_gen_Schmidt, index=["Experimental Generalised Schmidt value"], columns=col_names)
df_gen_Schmidt
# Out:
#                                         E115 Short chains  Dubna 3 Excl.
# Experimental Generalised Schmidt value           1.302724       1.032047

# %% [markdown]
# ### Simulation of expected values and confidence intervals

# %% [markdown]
# Via Monte-Carlo simulations the expected value and its confidence intervals can be obtained for the generalised Schmidt method. 10 000 sets of decay chains with the same structure as the experimental sets extracted above. Each decay step is simulated from an exponential distribution with an arbitrary decay constant (here $\lambda = 1$). Following this the exact same calculations are made as above. To get an idea of the behaviour of the method, a different number of decay steps, $n$, are included. 4 out of the 14 short chains only have two decay steps and to see the effect another index $l$ is introduced which represents the number of chains which have only two decay steps.

# %%
sim_names = ["$m=14$, $n=1$", "$m=14$, $n=2$", "$m=14$, $n=3$", "$m=14$, $n=1$, $l=4$", "Excl. D3"]
nbr_sets = 10000
df_temp = np.zeros(np.shape(l_df_short[0]))
l_df_sim = [df_temp[:,0], df_temp[:,0:2], df_temp, l_df_short[0], l_df_short[1]]

sim_Schmidt = np.empty((nbr_sets, len(sim_names)))

for i, df_sim in enumerate(l_df_sim):
    print("Set: ", i, sim_names[i])
    shape = (nbr_sets, *np.shape(df_sim))
    sim = np.random.exponential(scale=1, size=shape)
    if np.count_nonzero(np.isnan(df_sim)) > 0:
        for j in range(nbr_sets):
            sim[j][np.isnan(df_sim)] = np.nan
    theta = np.log(sim)
    theta_var = np.zeros(np.shape(theta))
    temp_Schmidt = np.zeros(np.shape(theta)[0:2])
    for j in range(nbr_sets):
        theta_var[j] = np.square(theta[j] - np.nanmean(theta[j], axis=0))
        temp_Schmidt[j] = g_nan_mean(theta_var[j])
    sim_Schmidt[:, i] = np.sqrt(np.mean(temp_Schmidt, axis=1))

sim_final_Schmidt = np.mean(sim_Schmidt, axis=0)
print(sim_final_Schmidt)
print("Done")
# Out:
# Set:  0 $m=14$, $n=1$
# Set:  1 $m=14$, $n=2$
# Set:  2 $m=14$, $n=3$
# Set:  3 $m=14$, $n=1$, $l=4$
# Set:  4 Excl. D3
# [ 1.19835343  0.92952466  0.83791004  0.86240062  0.85800212]
# Done

# %% [markdown]
# What follows is an illustration of the effect of the generalised Schmidt method (cf. Figure 3. in [D. Rudolph et al., EPJ Web of Conferences](https://www.epj-conferences.org/articles/epjconf/pdf/2016/12/epjconf_nn2016_01001.pdf)).

# %%
plt.figure(figsize=(12,10))
for i, l in enumerate(sim_names[0:-1]):
    plt.hist(sim_Schmidt[:,i], bins=100, color=colors[i], label=l, histtype='step', normed=True, lw=2)
plt.legend(loc='best',markerfirst=True, frameon=True,shadow=True,fancybox=True)
plt.xlabel(r"$\xi_{m,n,l}$")
plt.xlim((0.3,2.5))
plt.ylabel("Intensity")
plt.title(r"Distributions of $\xi_{m,n,l}$ for different sets of decay chains")
plt.tight_layout()
plt.show()

# %% [markdown]
# The more steps that are included (larger $n$) the smaller the distribution of $\xi_{m,n,l}$ becomes. Note that the blue curve corresponds to the standard Schmidt test.

# %% [markdown]
# ## Summary Generalised Schmidt Method

# %% [markdown]
# Consider the _Short_ E115 chains and the set with the D3 chain excluded. The following table compiles the experimental Generalised Schmidt values and from the simulations, the expected value and confidence interval.

# %%
s_gen_Schmidt = []
s_conf_int = "[{:1.2f}, {:1.2f}]"
s_gen_Schmidt.append(sim_final_Schmidt[3:])
s_gen_Schmidt.append([s_conf_int.format(np.percentile(sim_Schmidt[:,3], 5), np.percentile(sim_Schmidt[:,3], 95)), 
                     s_conf_int.format(np.percentile(sim_Schmidt[:,4], 5), np.percentile(sim_Schmidt[:,4], 95))])

df_gen_Schmidt.append(pd.DataFrame(data=s_gen_Schmidt, index=[r"Expected value of $\xi_{m,n,l}$", "90% confidence interval"], columns=df_gen_Schmidt.columns))
# Out:
#                                        E115 Short chains Dubna 3 Excl.
# Experimental Generalised Schmidt value           1.30272       1.03205
# Expected value of $\xi_{m,n,l}$                 0.862401      0.858002
# 90% confidence interval                     [0.62, 1.13]  [0.61, 1.14]

# %% [markdown]
# The complete set _E115 Short chains_ can be found outside the 90% confidence interval. As stated in [D. Rudolph et al., EPJ Web of Conferences](https://www.epj-conferences.org/articles/epjconf/pdf/2016/12/epjconf_nn2016_01001.pdf) : "Therefore, it is very unlikely that it is a mistake to conclude that not all chains originate from the same radioactive species".
#
# If the D3 chain is excluded from the set $\xi_{m,n,l}$ fits well within the limits obtained from the simulation. Hence, one cannot disregard an hypothesis that all chains in this set have a common origin. In the article exclusions of different chains are thoroughly examined.

# %% [markdown]
# # Figure-of-Merit (FoM) method

# %% [markdown]
# Described in [U. Forsberg et al., Nucl. Phys. A](http://www.sciencedirect.com/science/article/pii/S0375947416300768?via%3Dihub):
# > A FoM$^{(n)}_j$, defined for each correlation time $t^{(n)}_j$ decay step $j = 1, 2, 3$ of the chain identified by the number $n$, is calculated as the value of a probability density function for a reference data  set. The geometric mean of FoM$^{(n)}_j$ over all available steps $j$ in chain $n$ defines the FoM$^{(n)}_{geom}$ for that chain. The arithmetic mean of FoM$^{(n)}_{geom}$over all $N$ chains defines the FoM for the data set with respect to the interpretation under consideration.
#
# > If the individual chains all deviate strongly from the average data, the FoM value will be low. If the chains are all too similar to their average behaviour, the FoM will be high. The test is similar to the Schmidt test described above.  Note, however, that a low $\sigma_\theta$ corresponds to a large FoM and vice versa.
#
#
# > The probability density function is obtained through the following:
#
# > 1. For each step $j$, the average experimental lifetime $\bar{t}_j$ calculated, and the number of available lifetimes $N_j$ is noted.
# > 2. For each step $j$, the likelihood function for the true lifetime $\tau_j$, given by $N_j$ and $\bar{t}_j$, is  determined.
# > 3. For each step $j$, a $\tau_j$ is selected with a probability governed by the likelihood function for $\tau_j$, and then a set of $N_j$ lifetimes are generated from the exponential distribution defined by this $\tau_j$. This procedure is repeated until a smooth histogram emerges.

# %% [markdown]
# The analytical expression for this _smeared_ PDF for step $j$, using a reference data set with $N_j$ data points and average lifetime $\bar{t}_j$ in step $j$:
#
# \begin{equation}
# f(t)=t(N_j−1) \frac{ (N_j \bar{t}_j)^{N_j-1} }{ (N_j \bar{t}_j + t)^{N_j} }
# \end{equation}
#
# and it is obtained by weigthing an exponential distribution $g(t) = \frac{t}{\tau} e^{- \frac{t}{\tau} }$ with the normalised likelihood function for $\tau$:
#
# \begin{equation}
# h(\tau)= \frac{ N^{N-1} }{ (N-2)! }\frac{ \bar{t}^{N-1} }{ \tau^N } e^{- \frac{N\bar{t}}{\tau}}
# \end{equation}

# %% [markdown]
# The smeared probability density function eq. (2) is implemented as follows.

# %%
def pdf_smeared(times):
    """ Smeared probability density function, eq. (2)"""
    if isinstance(times, pd.DataFrame):
        times = times.as_matrix()
    N_j = np.count_nonzero(~np.isnan(times), axis=0)
    t_bar = np.nanmean(times, axis=0)
    ret = np.zeros((len(times[:]), len(N_j)))
    for i, t in enumerate(times[:]):
        temp = np.empty(len(t))
        prod = np.empty(len(t))
        np.multiply(N_j, t_bar, out=prod)
        np.power(prod, np.subtract(N_j,1), out=temp) #numerator
        np.divide(temp, np.power(np.add(prod, t), N_j), out=temp) #division with denominator
        np.multiply(temp, np.multiply(t, np.subtract(N_j, 1)), out=temp)
        ret[i] = temp
    return ret

# %% [markdown]
# The FoM$_j$ and FoM$_{geom}$ are calculated for the two sets of decay chains. Simultaneously the results are written to a table (cf. Table 4. in [U. Forsberg et al., Nucl. Phys. A](http://www.sciencedirect.com/science/article/pii/S0375947416300768?via%3Dihub)).

# %%
calc_names = ["E115 Short chains", "D3 Excl. "]
for i, df_now in enumerate(l_df_short):
    # Calculating FoM_j, FoM_geom and a final FoM for the complete set
    fom_j = pdf_smeared(df_now)
    fom_geom = g_nan_mean(fom_j)
    fom_final = np.mean(fom_geom)

    # Creating table in pandas data frame
    s_cols = 'FoM$_{}$'
    col_names = [s_cols.format(j) for j in range(len(fom_j[0]))]
    col_names.append('FoM$_{geom}$')
    header = pd.MultiIndex.from_product([[calc_names[i]], col_names])
    data = dict(zip(header, np.append(fom_j, fom_geom[:,np.newaxis], axis=1).T))
    df_temp = pd.DataFrame(data=data, index=df_now.index, columns=header)
    data = dict(zip(header, [ None, None, None, fom_final]))
    df_temp = df_temp.append(pd.DataFrame(data=data, index=[("FoM", '')], columns=header))
    if i == 0:
        df_fom = df_temp
    else:
        df_fom = pd.concat([df_fom, df_temp], axis=1, join_axes=[df_fom.index])
df_fom = df_fom.round(decimals=3)
display(df_fom)
# Out:
#             E115 Short chains                              D3 Excl.           \
#                       FoM$_0$ FoM$_1$ FoM$_2$ FoM$_{geom}$   FoM$_0$ FoM$_1$
# Lab      ID
# GSI      1              0.282   0.124     NaN        0.187     0.330   0.259
#          2              0.113   0.120     NaN        0.117     0.155   0.255
#          3              0.302   0.276   0.030        0.136     0.343   0.347
#          4              0.168   0.010   0.038        0.040     0.080   0.027
#          5              0.336   0.121   0.336        0.239     0.353   0.256
#          6              0.271   0.262   0.337        0.288     0.322   0.352
#          7              0.310   0.352   0.198        0.278     0.224   0.220
# Dubna    1              0.300   0.304   0.148        0.238     0.341   0.327
#          2              0.116   0.317   0.170        0.184     0.158   0.312
#          3              0.061   0.007   0.047        0.027       NaN     NaN
# ...

# %% [markdown]
# ## Simulations

# %% [markdown]
# ### Simulating sets of decay chains

# %% [markdown]
# The sets of decay chains are simulated in follows.
#
# For each decay step that exist in the set of decay chains:
# 1. For the decay step considered, a random $\tau_1$ is picked according to the $\tau$ likelihood function $h(\tau)$ (see eq. (3)).
# 2. A number of random lifetimes (corresponding to the number of lifetimes that exist in the studied set of decay chains) from the exponential distribution $g(t)$ defined by this $\tau_1$ is generated.

# %% [markdown]
# The $\tau$ likelihood function is first defined. In the following, all steps are treated simultaneously.

# %%
from scipy.special import factorial
class tau_likelihood_func(object):
    def __init__(self, times):
        if isinstance(times, pd.DataFrame):
            times = times.as_matrix()
        self.N_j = np.count_nonzero(~np.isnan(times), axis=0)
        self.t_bar = np.nanmean(times, axis=0)
        self.factor1 = np.divide(np.multiply(np.power(self.N_j, self.N_j-1), np.power(self.t_bar, self.N_j-1)), factorial(self.N_j-2))
        self.factor2 = -np.multiply(self.N_j, self.t_bar)
        #print("factor1=", self.factor1, np.shape(self.factor1))
                                 
    def __call__(self, tau):
        #ret = np.empty((len(tau), len(self.N_j)))
        #print(tau, np.shape(tau))
        ret = np.multiply(np.divide(self.factor1, np.power(tau, self.N_j)), np.exp(np.divide(self.factor2, tau)))
        return ret

# Two different tau likelihood functions are defined corresponding to the complete set of E115 short chains and the set with D3 excluded
tau_likelihoods = [tau_likelihood_func(l_df_short[0]), tau_likelihood_func(l_df_short[1])]

# %% [markdown]
# #### 1. Random sampling of $\tau$ from its likelihood function
#
# A numerical cumulative density function (CDF) is created from which the random samples of $\tau$ are generated.

# %%
# Creating points for the numerical CDFs
nbr_points = 10000
taus = []
tau_ls = []
cdfs = []

# looping sets of decay chains
for i, df_now in enumerate(l_df_short):
    print("t_mean=", tau_likelihoods[i].t_bar)
    tau = np.empty((nbr_points, len(df_now.columns)))
    # looping number of steps in set
    for j in range(len(tau[0])):
        tau[:,j] = np.linspace(0.00001, tau_likelihoods[i].t_bar[j]*4, len(tau[:,0]))
    tau_l = tau_likelihoods[i](tau)

    # Creating normalised CDFs 
    cdf = np.cumsum(tau_l, axis=0)
    cdf = np.divide(cdf, cdf[-1,:])
    
    # Storing in lists
    taus.append(tau)
    tau_ls.append(tau_l)
    cdfs.append(cdf)
    
# Plotting the CDF
labels = ["Step "+str(i+1) for i in range(len(l_df_short[0].columns))]
plt.figure()
for i, l in enumerate(labels):
    plt.plot(taus[0][:,i], cdfs[0][:,i], label=l)
plt.legend(loc='best',markerfirst=True, frameon=True,shadow=True,fancybox=True)
plt.xlabel(r"$\tau$ (s)")
plt.ylabel(r"CDF")
plt.title("Numerical CDF for the 3 decay steps")
plt.tight_layout()
plt.show()
# Out:
# t_mean= [  0.38494   4.23997  30.14064]
# t_mean= [  0.46971429   4.88583571  26.14457143]

# %% [markdown]
# Random sampling of $\tau$ from the numerical CDF for 100 000 sets of decay chains.

# %%
nbr_sets = 100000

rand_taus = []
# looping sets of decay chains
for ind, df_now in enumerate(l_df_short):
    #display(df_now)
    # Generating random numbers from uniform [0, 1)
    rands = np.random.rand(nbr_sets, len(df_now.columns))

    # Get the corresponding taus from the CDF
    rand_tau = np.empty(np.shape(rands))
    #looping number of steps in set
    for i in range(len(df_now.columns)):
        inds = np.searchsorted(cdfs[ind][:,i], rands[:,i])
        rand_tau[:,i] = taus[ind][inds,i]
    rand_taus.append(rand_tau)

# %% [markdown]
# Plotting the sampled $\tau$ for the existing decay steps of the complete set of E115 short chains.

# %%
f, axes = plt.subplots(3, 1, figsize=(10,8))# sharex=True, sharey=True)

# add a big axes, hide frame
f.add_subplot(111, frameon=False)
# hide tick and tick label of the big axes
plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')

# Plotting the sampled taus and their pdf:s
for i,ax in enumerate(axes):
    ax.plot(taus[0][:,i],tau_ls[0][:,i], color='black', label="Real PDF")
    ax.hist(rand_taus[0][:,i], bins=100, color=colors[i], normed=True, label="Sampled Distribution")
    #ax.annotate(an[i],xy=(0.75,.8), fontsize=24, xycoords='axes fraction', color='k')
    ax.legend(loc='upper right',markerfirst=False, title=r"$\bf{"+labels[i]+"}$", frameon=True, shadow=True, fancybox=True, fontsize=16)
    #ax.set_xscale('log')
    #ax.set_xlim(0.2)
plt.ylabel("PDF")
plt.xlabel(r"$\tau$ (s)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Simulating 100 000 sets of decay chains AND calculating their FoM values.
# This could take a minute or two.

# %%
sim_names = ["E115 Short Chains", "D3 Excl."]

l_df_sim = [l_df_short[0], l_df_short[1]]

sim_FoM = np.empty((nbr_sets, len(sim_names)))

#Looping over data sets as defined in l_df_sim
for i, df_sim in enumerate(l_df_sim):
    print("Set: ", i, sim_names[i])
    
    # Simulations of all random generated sets of decay chains
    shape = (nbr_sets, *np.shape(df_sim))
    print("Shape of current set of decay chains: ", np.shape(df_sim))
    sim = np.empty(shape)
    
    #looping over sets of decay chains
    for j in range(nbr_sets):
        #looping over steps in current set of decay chains and adding simulated lifetimes
        for k in range(len(df_sim.columns)):
            sim[j, :, k] = np.random.exponential(scale=rand_taus[i][j, k], size=shape[1])
    # if the current set of decay chains contains NaN (e.g. chains with one less decay step), substitute these in the simulated data
    if np.count_nonzero(np.isnan(df_sim)) > 0:
        for j in range(nbr_sets):
            sim[j][np.isnan(df_sim)] = np.nan
    print("    Simulated all sets of decay chains")
    print("     sim[0:2]=\n", sim[0:2])
    # FoM calculations
    fom = np.empty(shape[1:])
    fom_geom = np.empty(shape[1])
    for j in range(nbr_sets):
        fom = pdf_smeared(sim[j])
        fom_geom = g_nan_mean(fom)
        sim_FoM[j,i] = np.mean(fom_geom)
print("Done")
sim_FoM_mean = np.mean(sim_FoM, axis=0)
# Out:
# Set:  0 E115 Short Chains
# Shape of current set of decay chains:  (14, 3)
#     Simulated all sets of decay chains
#      sim[0:2]=
#  [[[  7.01131299e-01   3.54069566e-01              nan]
#   [  2.20553166e-01   4.95290353e+00              nan]
#   [  1.46768458e+00   9.29295631e-01   6.75877140e+00]
#   [  1.17546252e+00   1.15645448e-01   3.29473982e+00]
#   [  8.93641090e-01   8.38072999e-01   3.77884880e+00]
#   [  5.20066029e-01   7.78173102e+00   7.80729019e+00]
#   [  2.96784746e-01   3.74837913e-01   1.66264960e+01]
#   [  6.28741998e-01   6.38741268e+00   2.06540737e+01]
#   [  7.45833392e-02   2.04108297e+00   4.92733961e+00]
#   [  4.57319652e-01   2.41553056e+00   1.08622865e+01]
#   [  3.94620536e-01   1.11449634e-01   1.92452219e+01]
#   [  1.42569175e-01   1.26568730e+00   6.39326685e-01]
#   [  1.83779457e+00   8.90941409e-01              nan]
#   [  5.19586503e-01   1.59669045e+00              nan]]
#
#  [[  9.67374488e-02   4.85571792e-01              nan]
# ...

# %% [markdown]
# Plotting the distribution of the final FoM for the complete set of E115 short chains including expected value and 90% confidence interval.

# %%
plt.figure()
ax = plt.gca()
plt.hist(sim_FoM[:,0], bins=100, normed=True, label="FoM distribution")
ax.axvline(sim_FoM_mean[0], linestyle="--", color='k', label="Mean")
ax.vlines([np.percentile(sim_FoM[:,0], 5), np.percentile(sim_FoM[:,0], 95)], ymin=0, ymax=15, linestyle="--", color=colors[1], label="90% limits")
plt.xlabel("FoM")
plt.ylabel("Intensity")
plt.ylim((0, 25))
plt.xlim((0.15, 0.35))
plt.locator_params(axis='x', nbins=4)
#ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.2f'))
plt.legend(loc='best',markerfirst=True, frameon=True,shadow=True,fancybox=True)
plt.show()

# %% [markdown]
# ### Summary
#
# Expected values and confidence intervals obtained from the simulations are compared in the table generated through the following code.

# %%
col_names = [ "Simulation - E115 Short Chains", "Simulation - D3. Excl." ]
inds = ["FoM", "90% conf. interval", "95% conf. interval", "98% conf. interval"]

data = np.empty((len(col_names), len(inds)), dtype="<U20")
confs = [90, 95, 98]
s_conf_int = "[{:1.3f}, {:1.3f}]"
for i in range(len(col_names)):
    data[i, 0] = str(round(sim_FoM_mean[i], 4))
    for j, c in enumerate(confs):
        perc = 0.5*(100-c)
        data[i, j+1] = s_conf_int.format(np.percentile(sim_FoM[:,i], perc), np.percentile(sim_FoM[:,i], 100-perc))

data = dict(zip(col_names, data))
df_fom_sim = pd.DataFrame(data=data, index=inds, columns=col_names)
data = dict(zip(["E115 Short Chains", "D3 Excl."], [df_fom.iloc[-1, 3::-1].values, df_fom.iloc[-1, -1:3:-1].values]))
df_fom_sim = pd.concat([df_fom_sim, pd.DataFrame(data, index=df_fom_sim.index, columns=["E115 Short Chains", "D3 Excl."])], axis=1, join_axes=[df_fom_sim.index])
display(df_fom_sim)
# Out:
#                    Simulation - E115 Short Chains Simulation - D3. Excl.  \
# FoM                                        0.2295                 0.2297
# 90% conf. interval                 [0.194, 0.263]         [0.193, 0.265]
# 95% conf. interval                 [0.187, 0.269]         [0.186, 0.271]
# 98% conf. interval                 [0.179, 0.276]         [0.177, 0.277]
#
#                     E115 Short Chains  D3 Excl.
# FoM                             0.162     0.215
# 90% conf. interval                NaN       NaN
# 95% conf. interval                NaN       NaN
# 98% conf. interval                NaN       NaN

# %% [markdown]
# The conclusion from the table above is the following:
# * The complete set of short E115 chains fall out of all the confidence limits. Hence, the set is very unlikely to constitute a set of chains that have a common origin.
# * When excluding the D3 chain the FoM obtained is clearly within all confidence intervals. Therefore it is very likely that the D3 chain has a different origin than the rest of the set of short E115 chains.
#
# A much more thorough analysis and discussion is given in [U. Forsberg et al., Nucl. Phys. A](http://www.sciencedirect.com/science/article/pii/S0375947416300768?via%3Dihub).

# %% [markdown]
# # The alleged link between Element 117 and 115

# %% [markdown]
# ![](https://www.cmu.edu/news/stories/archives/2016/january/images/periodic_table_large.png "Pythagoras")

# %% [markdown]
# The fourth IUPAC/IUPAP Joint Working Party published a report with a review of the claims of the discovery of the new elements 113, 115, 117 & 118 [[Report](https://www.degruyter.com/view/j/pac.2016.88.issue-1-2/pac-2015-0502/pac-2015-0502.xml)]. In the report the joint working party concludes that the collaborations claims are in compliance with the set criteria.
#
# As stated in [U. Forsberg et al., Physics Letters B, ](http://www.sciencedirect.com/science/article/pii/S0370269316303495?via%3Dihub):
#
# > One indirect method to support that a new element was produced is via cross reactions or cross bombardments. The idea is that the same $\alpha$-decay chain is entered by two or more different nuclear reactions. For example, the $\alpha$-decay chains comprising the superheavy nuclei $^{289}$115, $^{285}$113 and $^{281}$Rg are considered to have been populated following two different fusion-evaporation reactions, namely via $^{243}$Am($^{48}$Ca,2n)$^{289}$115 and $^{249}$Bk($^{48}$Ca,4n)$^{293}$117.

# %% [markdown]
# The two main properties of a decay chain are the measured $\alpha$ energies and lifetimes of the radioactive isotopes.
# In the following it is evaluated of whether:
# > The cross reaction case for the isotopes $^{293}$117, $^{289}$117, $^{285}$113 and $^{281}$Rg presented in the IUPAC/IUPAP Joint Working Party [[Report](https://www.degruyter.com/view/j/pac.2016.88.issue-1-2/pac-2015-0502/pac-2015-0502.xml)] is probable.
#
# I.e. we want to evaluate of whether decay chains assigned to the isotopes $^{293}$117, $^{289}$117, $^{285}$113 and $^{281}$Rg have a common origin.
# Is there a link between Element 117 and 115?
#
# The assessment will be performed with the statistical FoM method presented above.
# Hence, lifetimes are merely considered.

# %% [markdown]
# ## Extracting data

# %% [markdown]
# The data used in the [Report](https://www.degruyter.com/view/j/pac.2016.88.issue-1-2/pac-2015-0502/pac-2015-0502.xml) is extracted. It constitutes:
# - The short E115 chains from Dubna.
# - 10 out of the 16 E117 chains.

# %%
# Extracting indices with E115/E117 and Short/Link and Dubna
s_extra_ind = 'Element'
m_inds = ['E115', 'E117']
df_links = [ df_all.loc['E115', 'Short', 'Dubna'], df_all.loc['E117', 'Link', 'Dubna'] ]

# Joining the two data frames and appending Element index
df_links_all = pd.concat(df_links, join='inner', keys=m_inds, names=[s_extra_ind])

# Sorting out columns with headers including Lifetime and removing columns with only NaN
df_links_all = df_links_all.filter(regex="Lifetime .* \(s\)").dropna(axis=1, how='all')

# Removing Lifetimes for E117 since these do not exist in both data sets
df_links_all = df_links_all.drop(columns=[df_links_all.columns[0], df_links_all.columns[-1]])

display(df_links_all)
# Out:
#             Lifetime E115 (s)  Lifetime E113 (s)  Lifetime Rg (s)
# Element ID
# E115    1              0.2562             1.4027           1.9775
#         2              0.0661             1.5500           2.3638
#         3              2.3507            22.5822          60.1855
#         4              0.0536             0.4671           0.0908
# E117    3              0.0175             1.1700          12.0300
#         4              0.5118             0.2380          31.6600
#         5              0.4244            13.4900          76.5600
#         6              0.2665             1.5155           9.4192
#         9              1.4348             1.3153         103.4060
#         10             0.1510            18.3997          42.1349
#         11             0.0136             0.4281          15.0551
#         12             0.9572             1.3712           4.7521
#         13             0.0565             4.2130           3.4642
# ...

# %% [markdown]
# Let's first visualise the lifetimes.

# %%
df_E115 = df_links_all.loc['E115'].T
df_E117 = df_links_all.loc['E117'].T

#ax = df_E115.plot(logy=True, use_index=True, xlim=(-0.1, 3), figsize=(10, 8), fontsize=14, color=colors[0], linestyle="--", marker="s")
plt.figure(figsize=(12, 10))
x = np.arange(len(df_E115.iloc[:,0]))
for i in range(len(df_E115.columns)):
    if i == 2: 
        c = 'red'
    else:
        c = 'blue'
    plt.plot(x, df_E115.iloc[:,i], label="D"+df_E115.columns[i], linestyle=":", marker="s", color=c)

# Averages
# All D
mu, sigma = np.mean(df_E115, axis=1), np.std(df_E115, axis=1)/len(x)
plt.plot(x, mu, color='purple', linestyle="-", label="Mean of D")
plt.fill_between(x, mu-sigma, mu+sigma, color='purple', linestyle="-", alpha=0.2)
# Removing D3, i.e. D'
df_Dp = df_E115.drop(columns='3')
mu, sigma = np.mean(df_Dp, axis=1), np.std(df_Dp, axis=1)/len(x)
plt.plot(x, mu, color='blue', linestyle="-", label="Mean of D \n (D3, excl.)")
plt.fill_between(x, mu-sigma, mu+sigma, color='blue', linestyle="-", alpha=0.2)
# All E117
mu, sigma = np.mean(df_E117, axis=1), np.std(df_E117, axis=1)/len(x)
plt.plot(x, mu, color='gray', linestyle="-", label="Mean of E117")
plt.fill_between(x, mu-sigma, mu+sigma, color='grey', linestyle="-", alpha=0.3)
plt.xlim((-0.1, 3.2))
plt.title("Lifetimes for chains linking E117 and E115")
plt.xticks(np.arange(3), ["E115", "E113", "Rg"], fontsize=18)
plt.ylabel("Lifetime (s)")
plt.xlabel("Decay step")
plt.yscale('log')
plt.legend(title=r"$\bf{Chains \ and \ sets}$ ")
plt.tight_layout()
plt.savefig("plot_linkE117.png")
plt.show()

# %% [markdown]
# Assuming that all chains labeled D1, D2, D3 and D4 should be grouped together, i.e. that they have a common origin has a huge effect on the average lifetimes.
# The implication of such an assumption is that the average lifetime of the element 115 chains are consistent with the element 117 chains.
# If such an interpretation is made, this would give support for a cross reaction case between element 117 and 115.
# However, is such an interpretation backed up by the statistical methods walked through in this document?
#
# We create four different sets of data:
# 1. All E117 chains (denoted E117).
# 2. All Dubna Short E115 and all E117 chains (denoted D & E117).
# 3. All Dubna Short E115 (D3 excluded) and all E117 chains (denoted D' & E117).
# 3. Dubna Short E115 chain D3 and all E117 chains (denoted D3 & E117).

# %%
names_df = ["E117", "D & E117", "D' & E117", "D3 & E117"]
l_df_links = [df_links_all.loc['E117'], df_links_all, df_links_all.drop(index=[('E115', '3')]), df_links_all.drop(index=[('E115', '1'), ('E115', '2'), ('E115', '4')])]
#display(df_links[3])

# %% [markdown]
# The FoM method is used and for every set:
# 1. The total FoM for is calculated as in section 4.
# 2. Confidence intervals are calculated by the means of Monte-Carlo simulations as described in section 4.1.

# %% [markdown]
# ## (i) Calculations

# %%
# Step 1; Calculations
fom_calc = np.empty(len(names_df))
for i, df_now in enumerate(l_df_links):
    fom_j = pdf_smeared(df_now)
    fom_geom = g_nan_mean(fom_j)
    fom_calc[i] = np.mean(fom_geom)
links_calc = pd.DataFrame(data={"FoM": fom_calc}, index=names_df)
links_calc.index.rename('Data set', inplace=True)
display(links_calc.round(decimals=3))
# Out:
#              FoM
# Data set
# E117       0.165
# D & E117   0.146
# D' & E117  0.155
# D3 & E117  0.160

# %% [markdown]
# ## (ii) Simulations

# %%
# Step 2; Simulations

tau_likelihoods = [] 
for df_now in l_df_links:
    tau_likelihoods.append(tau_likelihood_func(df_now))

# Creating points for the numerical CDFs
nbr_points = 10000
taus = []
tau_ls = []
cdfs = []
for i, df_now in enumerate(l_df_links):
    tau = np.empty((nbr_points, len(df_now.columns)))
    for j in range(len(tau[0])):
        tau[:,j] = np.linspace(0.00001, tau_likelihoods[i].t_bar[j]*4, len(tau[:,0]))
    tau_l = tau_likelihoods[i](tau)

    # Creating normalised CDFs 
    cdf = np.cumsum(tau_l, axis=0)
    cdf = np.divide(cdf, cdf[-1,:])
    
    # Storing in lists
    taus.append(tau)
    tau_ls.append(tau_l)
    cdfs.append(cdf)
    
print("Done")
# Out:
# Done

# %% [markdown]
# Random sampling from the numerical CDF for 100 000 sets of decay chains.

# %%
nbr_sets = 100000

# Generating random numbers from uniform [0, 1)
rand_taus = []
for ind, df_now in enumerate(l_df_links):
    rands = np.random.rand(nbr_sets, len(df_now.columns))

    # Get the corresponding taus from the CDF
    rand_tau = np.empty(np.shape(rands))
    for i in range(len(df_now.columns)):
        inds = np.searchsorted(cdfs[ind][:,i], rands[:,i])
        rand_tau[:,i] = taus[ind][inds,i]
    rand_taus.append(rand_tau)

print("Done")
# Out:
# Done

# %% [markdown]
# Simulating 100 000 sets of decay chains and calculating their FoM values. This could take a few minutes.

# %%
sim_FoM = np.empty((nbr_sets, len(names_df)))

#Looping over data sets as defined in l_df_sim
for i, df_sim in enumerate(l_df_links):
    print("Set: ", i, names_df[i])
    
    # Simulations of all random generated sets of decay chains
    shape = (nbr_sets, *np.shape(df_sim))
    sim = np.empty(shape)
    
    #looping over sets of decay chains
    for j in range(len(sim_FoM[:,0])):
        #looping over steps in current set of decay chains and adding simulated lifetimes
        for k in range(len(df_sim.columns)):
            sim[j, :, k] = np.random.exponential(scale=rand_taus[i][j, k], size=shape[1])
    # if the current set of decay chains contains NaN (e.g. chains with one less decay step), substitute these in the simulated data
    if np.count_nonzero(np.isnan(df_sim)) > 0:
        for j in range(nbr_sets):
            sim[j][np.isnan(df_sim)] = np.nan
    print("    Simulated all sets of decay chains")
    
    # FoM calculations
    fom = np.empty(shape[1:])
    fom_geom = np.empty(shape[1])
    for j in range(nbr_sets):
        fom = pdf_smeared(sim[j])
        fom_geom = g_nan_mean(fom)
        sim_FoM[j,i] = np.mean(fom_geom)
sim_FoM_mean = np.mean(sim_FoM, axis=0)
print("Done")
# Out:
# Set:  0 E117
#     Simulated all sets of decay chains
# Set:  1 D & E117
#     Simulated all sets of decay chains
# Set:  2 D' & E117
#     Simulated all sets of decay chains
# Set:  3 D3 & E117
#     Simulated all sets of decay chains
# Done

# %% [markdown]
# ## Results and Conclusions

# %%
col_names = [ "90%-interval", "98%-interval" ]

data = np.empty((len(col_names), len(l_df_links)), dtype="<U20")
confs = [90, 98]
s_conf_int = "[{:1.3f}, {:1.3f}]"
for i, c in enumerate(confs):
    perc = 0.5*(100-c)
    for j in range(len(l_df_links)):
        data[i, j] = s_conf_int.format(np.percentile(sim_FoM[:,j], perc), np.percentile(sim_FoM[:,j], 100-perc))

data = dict(zip(col_names, data))
links_calc_all = pd.concat([links_calc, pd.DataFrame(data, index=links_calc.index)], join='inner', axis=1, join_axes=[links_calc.index])
display(links_calc_all)
# Out:
#                 FoM    90%-interval    98%-interval
# Data set
# E117       0.164576  [0.188, 0.265]  [0.171, 0.279]
# D & E117   0.146308  [0.194, 0.261]  [0.179, 0.273]
# D' & E117  0.154623  [0.193, 0.261]  [0.178, 0.274]
# D3 & E117  0.160075  [0.190, 0.264]  [0.174, 0.277]

# %% [markdown]
# From the table it can be seen that neither of the FoM values for the data set fit inside the confidence intervals.
#
# The conclusion to draw from this is that with very high probability that neither of the four data sets have a common origin.
# Hence, the cross reaction case that have been presented in the IUPAC/IUPAP Joint Working Party [Report](https://www.degruyter.com/view/j/pac.2016.88.issue-1-2/pac-2015-0502/pac-2015-0502.xml) is not supported by the statistical analysis described here.
#
# [U. Forsberg et al., Physics Letters B, ](http://www.sciencedirect.com/science/article/pii/S0370269316303495?via%3Dihub) decribes the case in great detail.
